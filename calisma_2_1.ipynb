# %%
import cv2
cv2.__version__
# Out:
# '3.1.0'

# %%
import numpy as np
import matplotlib.pylab as plt
# %matplotlib inline

# %%
img = cv2.imread('racecar-j.jpg')

# %%
img.shape
# Out:
# (580, 1000, 3)

# %%
x_flag1 = 250
x_flag2 = 500
x_flag3 = 750
y_flag1 = 145
y_flag2 = 290
y_flag3 = 435

# %%
plt.axis("off")
plt.imshow(img)
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
parts=[]

# %%
part1 = img[:y_flag1,:x_flag1,:]
part2 = img[:y_flag1,x_flag1:x_flag2,:]
part3 = img[:y_flag1,x_flag2:x_flag3,:]
part4 = img[:y_flag1,x_flag3:,:]
part5 = img[y_flag1:y_flag2,:x_flag1,:]
part6 = img[y_flag1:y_flag2,x_flag1:x_flag2,:]
part7 = img[y_flag1:y_flag2,x_flag2:x_flag3,:]
part8 = img[y_flag1:y_flag2,x_flag3:,:]
part9 = img[y_flag2:y_flag3,:x_flag1,:]
part10 =img[y_flag2:y_flag3,x_flag1:x_flag2,:]
part11 =img[y_flag2:y_flag3,x_flag2:x_flag3,:]
part12 =img[y_flag2:y_flag3,x_flag3:,:]
part13 =img[y_flag3:,:x_flag1,:]
part14 =img[y_flag3:,x_flag1:x_flag2,:]
part15 =img[y_flag3:,x_flag2:x_flag3,:]
part16 =img[y_flag3:,x_flag3:,:]

# %%
parts=[part1,part2,part3,part4,part5,part6,part7,part8,part9,part10,part11,part12,part13,part14,part15,part16]

# %%
for part_img in parts:   
    plt.axis("off")
    plt.imshow(part_img)
    plt.show()

# %%
new_img = np.zeros_like(img)
new_img[:y_flag1,:x_flag1,:]=parts[4]
new_img[:y_flag1,x_flag1:x_flag2,:]=parts[3]
new_img[:y_flag1,x_flag2:x_flag3,:]=parts[15]
new_img[:y_flag1,x_flag3:,:]=parts[9]
new_img[y_flag1:y_flag2,:x_flag1,:]=parts[12]
new_img[y_flag1:y_flag2,x_flag1:x_flag2,:]=parts[1]
new_img[y_flag1:y_flag2,x_flag2:x_flag3,:]=parts[14]
new_img[y_flag1:y_flag2,x_flag3:,:]=parts[8]
new_img[y_flag2:y_flag3,:x_flag1,:]=parts[6]
new_img[y_flag2:y_flag3,x_flag1:x_flag2,:]=parts[0]
new_img[y_flag2:y_flag3,x_flag2:x_flag3,:]=parts[2]
new_img[y_flag2:y_flag3,x_flag3:,:]=parts[5]
new_img[y_flag3:,:x_flag1,:]=parts[13]
new_img[y_flag3:,x_flag1:x_flag2,:]=parts[11]
new_img[y_flag3:,x_flag2:x_flag3,:]=parts[7]
new_img[y_flag3:,x_flag3:,:]=parts[10]

# %%
plt.axis("off")
plt.imshow(new_img)
plt.show()

# %%
cv2.imwrite('swapped.jpg',new_img)
# Out:
# True
